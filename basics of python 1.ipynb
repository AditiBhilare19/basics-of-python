# %%
#Name:Aditi bhilare
#roll no:9104

# %% [markdown]
# The bool() function allows and give you true or false

# %%
print(bool(10>9))
print(bool(10==0))
print(bool(10<9))
# Out:
# True
# False
# False

# %%
x="hello"
y=15
print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
#some values are false 
print(bool(False))
print(bool(None))
print(bool(0))
print (bool(""))
print(bool(()))
print(bool([]))
print(bool({}))
# Out:
# False
# False
# False
# False
# False
# False
# False

# %%
x,y=15,9
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
x=8
print(x<5 and x<10)
print(x<5 or x<10)
print (not(x>10))
print(not(x<5 and x<10))
# Out:
# False
# True
# True
# True

# %%
x,y=2,10
print(x is y)
print(x is not y)
# Out:
# False
# True

# %%
x,y='Hi','Hi'
print (x is y)
print (x is not y)
# Out:
# True
# False

# %% [markdown]
# membership operators
# *in
# *not in

# %%
x="have a good day"
print ("have" in x)
print("h" in x)
print("av" in x )
print("good day" in  x)
# Out:
# True
# True
# True
# True

# %%
a="is not in pune"
print ("pune" in a)
# Out:
# True

# %% [markdown]
# Positive Indexing starts from 0(goes from left to right)
#
#
# Negative Indexing starts from -1(goes from right to left)

# %%
a="I like Python"
print(a[-11:-7])
print(a[2:6])
# Out:
# like
# like
